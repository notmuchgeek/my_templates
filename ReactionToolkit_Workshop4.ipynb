# %%
# %pylab inline  
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import pandas as pd
from scipy.signal import find_peaks
import plotly.graph_objects as go

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## define loadtxt

# %%
import os

#Universal path for the working dictionary
PATH = 'C:/Users/AlbertCielstian/Documents/GitHub/y3_BPES_cw01/data/'

files = os.listdir(PATH)

for file in files:
    print(file)

# %%
def load_d(name):
    xy_data=np.loadtxt(PATH+str(name),skiprows=0)

    x1=[]
    y1=[]
    for i in xy_data:
        x1.append(i[0])
        y1.append(float(i[1]))
    return np.array(x1), np.array(y1)

# %%
g_year,g = load_d('div_growth_by_year.txt')
rm_year,rm = load_d('div_anual_total_return.txt')
div_year,div = load_d('div_by_year.txt')

# %% [markdown]
# ## Basic plot example

# %%
fig, ax = plt.subplots()

plt.title('Dividend Growth By Year')
ax.plot(g_year,g, linewidth=1,label = 'Div growth (g)', marker='.')


ax.set_xlabel('year')
ax.set_ylabel('div growth (g)')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 1 - linear fit

# %%
# 
time = linspace(0, 4000, 9)
conc = array([16.6, 12.6, 11.4, 9.5, 7.6, 6.3, 5.0, 4.4, 3.5])
conc = np.log(conc)
#conc = conc

# %% [markdown]
# plot(time, conc)

# %%
fit_para = polyfit(time, conc, 1, cov=True)
m = fit_para[0][0]
c = fit_para[0][1]
print('m:', m, 'c:', c)
# Out:
# m: -0.0003813976259236621 c: 2.78951835916625

# %%
title('first-order', fontsize=14)
plot(time, m*time+c)
plot(time, conc, linestyle='', marker='^')
xlabel('time/s')
ylabel('ln(conc)/ $mol*L^{-1}$')
# Out:
# Text(0, 0.5, 'ln(conc)/ $mol*L^{-1}$')

# %%
np.log(2)/m
# Out:
# -1817.3872448243314

# %% [markdown]
# ## Polyfit

# %%
import matplotlib.pyplot as plt
import numpy as np
from lmfit import Model

t = div_year[:25]

v = div[:25]

def func(t, a, b, alpha):
    return a + b * np.exp(-alpha * t)

# remove first data point, take offset from t
tx = t[1:] - t[0]
vx = v[1:]

# turn your model function into a Model
amodel = Model(func)
# create parameters with initial values.  Note that parameters
# are named from the arguments of your model function.
params = amodel.make_params(a=v[0], b=0, alpha=1.0/(t[-1]-t[0]))

# fit the data to the model with the parameters
result = amodel.fit(vx, params, t=tx)

# print the fit statistics and resulting parameters
print(result.fit_report())

# plot data and fit
plt.plot(t, v, 'o', label='data')
plt.plot(t, result.eval(result.params, t=(t-t[0])), '--', label='fit')
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 2

# %%
plt.rcParams['figure.figsize'] = [8, 6]

fig, ax1 = plt.subplots()



ax2 = ax1.twinx()
ax1.plot(grids, area_list,color='g',marker='.',linestyle='-')
ax2.plot(grids, times,color='r',marker='.',linestyle='-')

ax1.set_xlabel('Size of the grip (N)')
ax1.set_ylabel('Area under the DOS plots', color='g')
ax2.set_ylabel('CPU time / s', color='r')


plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 3

# %%
date_divPay,div_divPay = load_d('div_payout.csv')



fig, ax = plt.subplots()
plt.title('DivPay')
ax.plot(div_divPay, linewidth=1,label = 'DivPay', marker='.')

ax.set_xlabel('Date')
ax.set_ylabel('divPay')

ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

#ax.set_xlim(0,0.3)

ax.legend()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 4

# %%
# print the code by itself
color = iter(cm.rainbow(np.linspace(0, 1, len(opt_E_list))))


for n in range(len(opt_E_list)):
    print(ini_a_str[n] , "=" , opt_E_list[n] , )
