# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = [0.599712928, 0.58792499, 0.257029832, 0.605302274, 0.705494347, 
     0.317942015, 0.442060369, 0.467518859, 0.528231887, 0.413662109, 
     0.735287541, 0.206967732, 0.613149735, 0.809847914]
plt.figure(figsize=(8,6))

plt.hist(x, bins = 13)
plt.xlabel('Shrinkage (dried after/deried before)')
plt.ylabel('Frequency')
plt.show()

# %%
norm = [0.599712928, 0.58792499, 0.257029832, 0.605302274, 0.705494347, 
     0.317942015, 0.442060369, 0.467518859]
gly = [ 0.528231887, 0.413662109, 
     0.735287541, 0.206967732, 0.613149735, 0.809847914]

# %%
plt.plot(np.arange(len(norm)),norm)
plt.plot(np.arange(len(gly)),gly,linestyle = '',marker = '.')
